# %%
# sentiment_analysis_novel_with_custom_loss.py

import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from transformers import BertTokenizer, TFBertModel
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
import re
import nltk
from nltk.corpus import stopwords
from spektral.layers import GATConv, TopKPool
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
import logging

# -------------------------------
# 0. Environment Setup
# -------------------------------

# Set random seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

set_seed(42)

# Suppress TensorFlow warnings for cleaner output
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# -------------------------------
# 1. Data Preparation
# -------------------------------

# Load the dataset
df = pd.read_csv(r"F:\Context-Resonance Transformer\Restuarant\Restaurant - Sheet1.csv")  # Replace with your dataset path
df = df[['Text', 'Category', 'Polarity']]
print("Initial DataFrame:")
print(df.head())
print(f"Initial Data Shape: {df.shape}")

# Initialize Bengali stopwords
nltk.download('stopwords')

# Load Bengali stopwords
try:
    stop_words = set(stopwords.words('bengali'))
except LookupError:
    print("Bengali stopwords not found. Skipping stopword removal.")
    stop_words = set()

# Function to clean text
def clean_text(text):
    text = re.sub(r'[^\u0980-\u09FF\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    words = text.split()
    if stop_words:
        words = [word for word in words if word not in stop_words]
    return ' '.join(words)

df['Text'] = df['Text'].apply(clean_text)
print("DataFrame after text cleaning:")
print(df.head())

# Upsample classes to balance the dataset
from sklearn.utils import resample

def upsample(df, target_column):
    max_count = df[target_column].value_counts().max()
    upsampled_dfs = []
    for label in df[target_column].unique():
        df_label = df[df[target_column] == label]
        df_upsampled = resample(
            df_label,
            replace=True,
            n_samples=max_count,
            random_state=42
        )
        upsampled_dfs.append(df_upsampled)
    return pd.concat(upsampled_dfs)

df_upsampled_category = upsample(df, 'Category')
df_upsampled_polarity = upsample(df_upsampled_category, 'Polarity')

df_upsampled = df_upsampled_polarity.sample(frac=1, random_state=42).reset_index(drop=True)

# Encode labels
category_encoder = LabelEncoder()
polarity_encoder = LabelEncoder()

df_upsampled['Category_encoded'] = category_encoder.fit_transform(df_upsampled['Category'])
df_upsampled['Polarity_encoded'] = polarity_encoder.fit_transform(df_upsampled['Polarity'])

# Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

def tokenize_sentences(sentences, tokenizer, max_len=20, batch_size=32):
    input_ids = []
    attention_masks = []
    for i in tqdm(range(0, len(sentences), batch_size), desc="Tokenizing"):
        batch = sentences[i:i+batch_size]
        encoded = tokenizer(
            list(batch),
            add_special_tokens=True,
            max_length=max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='tf'
        )
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])
    input_ids = tf.concat(input_ids, axis=0).numpy()
    attention_masks = tf.concat(attention_masks, axis=0).numpy()
    return input_ids, attention_masks

# Tokenize the data
input_ids, attention_masks = tokenize_sentences(df_upsampled['Text'].values, tokenizer, max_len=20, batch_size=32)

# Create window-based adjacency matrices
def window_based_adjacency(sentences, window_size=2, max_len=20):
    adjacency_matrices = []
    for sentence in sentences:
        tokens = sentence.split()[:max_len]
        num_tokens = len(tokens)
        adj = np.zeros((max_len, max_len), dtype=np.float32)
        for i in range(num_tokens):
            for j in range(max(i - window_size, 0), min(i + window_size + 1, num_tokens)):
                if i != j:
                    adj[i, j] = 1.0
        adjacency_matrices.append(adj)
    return np.array(adjacency_matrices, dtype=np.float32)

adjacency_matrices = window_based_adjacency(df_upsampled['Text'].values, window_size=2, max_len=20)

# Define labels
labels_category = df_upsampled['Category_encoded'].values
labels_polarity = df_upsampled['Polarity_encoded'].values

# Split the data
X_train_ids, X_test_ids, X_train_masks, X_test_masks, adjacency_train, adjacency_test, y_train_category, y_test_category, y_train_polarity, y_test_polarity = train_test_split(
    input_ids, attention_masks, adjacency_matrices, labels_category, labels_polarity, test_size=0.2, random_state=42, stratify=labels_category
)
# Out:
# Initial DataFrame:
#                                                 Text                 Category  \
# 0              স্টাফ কিন্তু, আমাদের জন্য ভয়ঙ্কর ছিল।                  service
# 1  শুধুমাত্র,রিডামিং ফ্যাক্টর খাদ্য ছিল,পুরোপুরি ...                     food
# 2  শুধুমাত্র,রিডামিং ফ্যাক্টর খাদ্য ছিল,পুরোপুরি ...  anecdotes/miscellaneous
# 3  খাবার একদমই ব্যতিক্রমী, একটি খুব সক্ষম রান্নাঘ...                     food
# 4  যেখানে গাব্রিয়েলা লোকালি আপনাকে শুভেচ্ছা জানা...                  service
#
#    Polarity
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  positive
# Initial Data Shape: (2059, 3)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mhose\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# DataFrame after text cleaning:
#                                                 Text                 Category  \
# 0                                       স্টাফ ভয়ঙ্কর                  service
# 1  শুধুমাত্ররিডামিং ফ্যাক্টর খাদ্য ছিলপুরোপুরি ন্...                     food
# 2  শুধুমাত্ররিডামিং ফ্যাক্টর খাদ্য ছিলপুরোপুরি ন্...  anecdotes/miscellaneous
# 3  খাবার একদমই ব্যতিক্রমী সক্ষম রান্নাঘর গর্বের খ...                     food
# 4  গাব্রিয়েলা লোকালি আপনাকে শুভেচ্ছা আপনাকে খেতে...                  service
#
#    Polarity
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  positive
# f:\Mini Conda\envs\env\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Tokenizing: 100%|██████████| 258/258 [00:02<00:00, 86.10it/s]

# %%
# -------------------------------
# 2. Model Architecture
# -------------------------------

from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, Concatenate, Embedding, Flatten, Layer
from tensorflow.keras.models import Model
from spektral.layers import GATConv

def squash(vectors):
    s_squared_norm = tf.reduce_sum(tf.square(vectors), axis=-1, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm)
    unit_vectors = vectors / tf.sqrt(s_squared_norm + 1e-9)
    return scale * unit_vectors

# Custom Multi-Head Attention Layer
class CustomMultiHeadAttention(Layer):
    def __init__(self, num_heads, key_dim, max_len, **kwargs):
        super(CustomMultiHeadAttention, self).__init__(**kwargs)
        self.num_heads = num_heads
        self.key_dim = key_dim
        self.depth = key_dim // num_heads
        self.max_len = max_len

    def build(self, input_shape):
        if isinstance(input_shape, list) and len(input_shape) == 3:
            q_shape, k_shape, v_shape = input_shape
        else:
            q_shape = input_shape
            k_shape = input_shape
            v_shape = input_shape
        self.wq = self.add_weight(shape=(q_shape[-1], self.key_dim), initializer='random_normal', trainable=True)
        self.wk = self.add_weight(shape=(k_shape[-1], self.key_dim), initializer='random_normal', trainable=True)
        self.wv = self.add_weight(shape=(v_shape[-1], self.key_dim), initializer='random_normal', trainable=True)
        super(CustomMultiHeadAttention, self).build(input_shape)

    def split_heads(self, x):
        batch_size = tf.shape(x)[0]
        x = tf.reshape(x, (batch_size, self.max_len, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])  # (batch_size, num_heads, seq_len, depth)

    def call(self, inputs, mask=None):
        if isinstance(inputs, list) and len(inputs) == 3:
            q, k, v = inputs
        else:
            q = inputs
            k = inputs
            v = inputs
        batch_size = tf.shape(q)[0]

        q = tf.matmul(q, self.wq)
        k = tf.matmul(k, self.wk)
        v = tf.matmul(v, self.wv)

        q = self.split_heads(q)
        k = self.split_heads(k)
        v = self.split_heads(v)

        # Scaled dot-product attention
        matmul_qk = tf.matmul(q, k, transpose_b=True)
        dk = tf.cast(self.depth, tf.float32)
        scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

        if mask is not None:
            scaled_attention_logits += (mask * -1e9)

        attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

        output = tf.matmul(attention_weights, v)
        output = tf.transpose(output, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(output, (batch_size, self.max_len, self.key_dim))

        # Set shapes for Keras
        concat_attention.set_shape((None, self.max_len, self.key_dim))
        attention_weights.set_shape((None, self.num_heads, self.max_len, self.max_len))

        return concat_attention, attention_weights

    def compute_output_shape(self, input_shape):
        if isinstance(input_shape, list):
            batch_size = input_shape[0][0]
        else:
            batch_size = input_shape[0]
        return (batch_size, self.max_len, self.key_dim)



# Updated GNNContextResonance Layer without TopKPool
class GNNContextResonance(tf.keras.layers.Layer):
    def __init__(self, hidden_size, num_heads=8, max_len=20, dropout_rate=0.2, **kwargs):
        super(GNNContextResonance, self).__init__(**kwargs)
        self.hidden_size = hidden_size
        self.num_heads = num_heads
        self.max_len = max_len
        self.dropout_rate = dropout_rate

        # Positional Encoding
        self.position_embedding = Embedding(input_dim=max_len, output_dim=hidden_size)

        # Multi-Head GAT Layers with Edge Attention and Residual Connections
        self.gat_layers = [GATConv(hidden_size // num_heads, activation='elu') for _ in range(num_heads)]
        self.concat = Concatenate()

        # Highway Network for Modulation
        self.transform_gate = Dense(hidden_size, activation='sigmoid')
        self.carry_gate = Dense(hidden_size, activation='sigmoid')

        # Dropout and Layer Norm
        self.dropout = Dropout(dropout_rate)
        self.layer_norm = LayerNormalization(epsilon=1e-6)

        # Dense layer for resonance scores
        self.dense = Dense(1, activation='sigmoid')

    def call(self, inputs, adjacency, edge_features=None, training=False):
        """
        inputs: BERT embeddings (batch_size, seq_length, hidden_size)
        adjacency: Adjacency matrices (batch_size, seq_length, seq_length)
        edge_features: Edge features (batch_size, seq_length, seq_length, edge_feature_dim)
        """
        # Positional Encoding
        position_indices = tf.range(self.max_len)[tf.newaxis, :]
        position_embeddings = self.position_embedding(position_indices)
        inputs = inputs + position_embeddings

        # Multi-Head GAT
        gat_outputs = []
        for gat_layer in self.gat_layers:
            x = gat_layer([inputs, adjacency])
            gat_outputs.append(x)
        x = self.concat(gat_outputs)  # Concatenate outputs from all heads

        # Residual Connection
        x = x + inputs  # Residual connection

        # Removed Graph Pooling Layer

        # Highway Network for Modulation
        transform = self.transform_gate(x)
        carry = self.carry_gate(inputs)
        outputs = transform * x + (1 - transform) * carry

        # Apply dropout and layer normalization
        outputs = self.dropout(outputs, training=training)
        outputs = self.layer_norm(outputs)

        # Compute resonance scores
        resonance_scores = self.dense(outputs)

        return outputs, resonance_scores
    

    
def build_model_with_gnn(bert_model, hidden_size, max_len=20):
    # Define Inputs
    input_ids = Input(shape=(max_len,), dtype=tf.int32, name='input_ids')
    attention_masks = Input(shape=(max_len,), dtype=tf.int32, name='attention_masks')
    adjacency = Input(shape=(max_len, max_len), dtype=tf.float32, name='adjacency')

    # Get BERT embeddings
    bert_outputs = bert_model([input_ids, attention_masks])
    sequence_output = bert_outputs.last_hidden_state  # (batch_size, seq_length, hidden_size)

    # Apply GNN-Based ContextResonance
    gnn_resonance_layer = GNNContextResonance(hidden_size, num_heads=8, max_len=max_len)
    gnn_output, resonance_scores = gnn_resonance_layer(sequence_output, adjacency)

    # Implement Dual Attention Mechanism
    # Self-attention over GNN outputs
    self_attention_layer = CustomMultiHeadAttention(num_heads=8, key_dim=hidden_size, max_len=max_len)
    self_attention_output, self_attention_scores = self_attention_layer([gnn_output, gnn_output, gnn_output])

    # Cross-attention between BERT outputs and GNN outputs
    cross_attention_layer = CustomMultiHeadAttention(num_heads=8, key_dim=hidden_size, max_len=max_len)
    cross_attention_output, cross_attention_scores = cross_attention_layer([sequence_output, gnn_output, gnn_output])

    # Combine outputs
    combined_output = Concatenate(axis=-1)([self_attention_output, cross_attention_output])

    # Apply Capsule Networks After GNN
    caps_num_capsules = 10  # Number of capsules
    caps_dim_capsules = 16  # Dimension of each capsule

    # Primary Capsule Layer
    primary_capsules = tf.keras.layers.Conv1D(
        filters=caps_num_capsules * caps_dim_capsules,
        kernel_size=1,
        strides=1,
        padding='valid'
    )(combined_output)

    primary_capsules = tf.keras.layers.Reshape(
        target_shape=(max_len, caps_num_capsules, caps_dim_capsules)
    )(primary_capsules)

    primary_capsules = tf.keras.layers.Lambda(squash, name='primary_caps_squash')(primary_capsules)

    # Flatten capsules
    flat_capsules = Flatten()(primary_capsules)

    # Classification Heads for Hierarchical Multi-Task Learning
    dropout = Dropout(0.3)(flat_capsules)

    # Category Output
    category_output = Dense(len(category_encoder.classes_), activation='softmax', name='category_output')(dropout)

    # Combine flat capsules and category prediction for polarity prediction
    combined_input = Concatenate()([dropout, category_output])

    # Polarity Output uses combined input
    polarity_dropout = Dropout(0.3)(combined_input)
    polarity_output = Dense(len(polarity_encoder.classes_), activation='softmax', name='polarity_output')(polarity_dropout)

    # Include `flat_capsules` and attention scores in the outputs
    model = Model(
        inputs=[input_ids, attention_masks, adjacency],
        outputs=[category_output, polarity_output, resonance_scores, flat_capsules, self_attention_scores, cross_attention_scores]
    )

    return model

# Load pre-trained multilingual BERT model
bert_model = TFBertModel.from_pretrained('bert-base-multilingual-cased')
hidden_size = bert_model.config.hidden_size  # Typically 768

# Build the model
model = build_model_with_gnn(bert_model, hidden_size, max_len=20)

# Summary of the model
model.summary()
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# f:\Mini Conda\envs\env\lib\site-packages\keras\initializers\initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 20)]         0           []
#
#  attention_masks (InputLayer)   [(None, 20)]         0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  177853440   ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_masks[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 20,
#                                 768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  adjacency (InputLayer)         [(None, 20, 20)]     0           []
#
#  gnn_context_resonance (GNNCont  ((None, 20, 768),   1790977     ['tf_bert_model[0][0]',
#  extResonance)                   (None, 20, 1))                   'adjacency[0][0]']
#
#  custom_multi_head_attention (C  ((None, 20, 768),   1769472     ['gnn_context_resonance[0][0]',
#  ustomMultiHeadAttention)        (None, 8, 20, 20))               'gnn_context_resonance[0][0]',
#                                                                   'gnn_context_resonance[0][0]']
#
#  custom_multi_head_attention_1   ((None, 20, 768),   1769472     ['tf_bert_model[0][0]',
#  (CustomMultiHeadAttention)      (None, 8, 20, 20))               'gnn_context_resonance[0][0]',
#                                                                   'gnn_context_resonance[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 20, 1536)     0           ['custom_multi_head_attention[0][
#                                                                  0]',
#                                                                   'custom_multi_head_attention_1[0
#                                                                  ][0]']
#
#  conv1d (Conv1D)                (None, 20, 160)      245920      ['concatenate_1[0][0]']
#
#  reshape (Reshape)              (None, 20, 10, 16)   0           ['conv1d[0][0]']
#
#  primary_caps_squash (Lambda)   (None, 20, 10, 16)   0           ['reshape[0][0]']
#
#  flatten (Flatten)              (None, 3200)         0           ['primary_caps_squash[0][0]']
#
#  dropout_38 (Dropout)           (None, 3200)         0           ['flatten[0][0]']
#
#  category_output (Dense)        (None, 5)            16005       ['dropout_38[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 3205)         0           ['dropout_38[0][0]',
#                                                                   'category_output[0][0]']
#
#  dropout_39 (Dropout)           (None, 3205)         0           ['concatenate_2[0][0]']
#
#  polarity_output (Dense)        (None, 4)            12824       ['dropout_39[0][0]']
#
# ==================================================================================================
# Total params: 183,458,110
# Trainable params: 183,458,110
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# -------------------------------
# 3. Defining Custom Loss Functions and Metrics
# -------------------------------

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5, epsilon=1e-08)

# Define the standard loss functions with 'none' reduction to get per-sample losses
loss_fn_category = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
loss_fn_polarity = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)

# Define metrics
train_accuracy_category = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy_category')
train_accuracy_polarity = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy_polarity')
val_accuracy_category = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy_category')
val_accuracy_polarity = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy_polarity')

# Compute class weights based on the training labels for both tasks
class_weights_category = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_category),
    y=y_train_category
)

class_weights_polarity = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_polarity),
    y=y_train_polarity
)

# Convert class_weights to dictionaries for easy lookup
class_weights_dict_category = {i: weight for i, weight in enumerate(class_weights_category)}
class_weights_dict_polarity = {i: weight for i, weight in enumerate(class_weights_polarity)}
print("Category Class Weights:", class_weights_dict_category)
print("Polarity Class Weights:", class_weights_dict_polarity)

# Define the supervised contrastive loss function
def supervised_contrastive_loss(labels, features, temperature=0.1):
    labels = tf.reshape(labels, [-1])
    label_mask = tf.equal(tf.expand_dims(labels, 0), tf.expand_dims(labels, 1))
    features = tf.math.l2_normalize(features, axis=1)
    similarity_matrix = tf.matmul(features, features, transpose_b=True) / temperature
    logits_max = tf.reduce_max(similarity_matrix, axis=1, keepdims=True)
    logits = similarity_matrix - logits_max
    exp_logits = tf.exp(logits) * tf.cast(label_mask, tf.float32)
    log_prob = logits - tf.math.log(tf.reduce_sum(exp_logits, axis=1, keepdims=True) + 1e-8)
    mean_log_prob_pos = tf.reduce_sum(log_prob * tf.cast(label_mask, tf.float32), axis=1) / tf.reduce_sum(tf.cast(label_mask, tf.float32), axis=1)
    loss = -tf.reduce_mean(mean_log_prob_pos)
    return loss

# -------------------------------
# 4. Custom Training Loop
# -------------------------------

@tf.function
def train_step(input_ids, attention_masks, adjacency, labels_category, labels_polarity):
    with tf.GradientTape() as tape:
        # Forward pass
        predictions = model([input_ids, attention_masks, adjacency], training=True)
        predictions_category = predictions[0]
        predictions_polarity = predictions[1]
        resonance_scores = predictions[2]
        features = predictions[3]

        # Compute per-sample standard loss for category
        cce_loss_category = loss_fn_category(labels_category, predictions_category)

        # Compute per-sample standard loss for polarity
        cce_loss_polarity = loss_fn_polarity(labels_polarity, predictions_polarity)

        # Apply class weights
        class_weights_tensor_category = tf.gather(tf.constant(class_weights_category, dtype=tf.float32), labels_category)
        class_weights_tensor_polarity = tf.gather(tf.constant(class_weights_polarity, dtype=tf.float32), labels_polarity)

        weighted_cce_loss_category = cce_loss_category * class_weights_tensor_category
        weighted_cce_loss_category_mean = tf.reduce_mean(weighted_cce_loss_category)

        weighted_cce_loss_polarity = cce_loss_polarity * class_weights_tensor_polarity
        weighted_cce_loss_polarity_mean = tf.reduce_mean(weighted_cce_loss_polarity)

        # Compute smoothness loss
        resonance_scores_squeezed = tf.squeeze(resonance_scores, axis=-1)  # (batch_size, seq_length)
        resonance_diff = resonance_scores_squeezed[:, :, tf.newaxis] - resonance_scores_squeezed[:, tf.newaxis, :]
        squared_diff = tf.square(resonance_diff)
        smoothness_loss = tf.reduce_sum(adjacency * squared_diff, axis=[1,2])  # (batch_size,)
        smoothness_loss = tf.reduce_mean(smoothness_loss)

        # Compute contrastive loss on the features
        contrastive_loss_value = supervised_contrastive_loss(labels_category, features)

        # Total loss
        alpha = 0.1  # Weight for smoothness loss
        beta = 0.1   # Weight for contrastive loss
        total_loss = (weighted_cce_loss_category_mean + weighted_cce_loss_polarity_mean
                      + alpha * smoothness_loss + beta * contrastive_loss_value)

    # Compute gradients
    gradients = tape.gradient(total_loss, model.trainable_variables)

    # Update weights
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Update metrics
    train_accuracy_category.update_state(labels_category, predictions_category)
    train_accuracy_polarity.update_state(labels_polarity, predictions_polarity)

    return total_loss, weighted_cce_loss_category_mean, weighted_cce_loss_polarity_mean, smoothness_loss, contrastive_loss_value

@tf.function
def test_step(input_ids, attention_masks, adjacency, labels_category, labels_polarity):
    # Forward pass
    predictions = model([input_ids, attention_masks, adjacency], training=False)
    predictions_category = predictions[0]
    predictions_polarity = predictions[1]
    resonance_scores = predictions[2]
    features = predictions[3]

    # Compute per-sample standard loss for category
    cce_loss_category = loss_fn_category(labels_category, predictions_category)

    # Compute per-sample standard loss for polarity
    cce_loss_polarity = loss_fn_polarity(labels_polarity, predictions_polarity)

    # Apply class weights
    class_weights_tensor_category = tf.gather(tf.constant(class_weights_category, dtype=tf.float32), labels_category)
    class_weights_tensor_polarity = tf.gather(tf.constant(class_weights_polarity, dtype=tf.float32), labels_polarity)

    weighted_cce_loss_category = cce_loss_category * class_weights_tensor_category
    weighted_cce_loss_category_mean = tf.reduce_mean(weighted_cce_loss_category)

    weighted_cce_loss_polarity = cce_loss_polarity * class_weights_tensor_polarity
    weighted_cce_loss_polarity_mean = tf.reduce_mean(weighted_cce_loss_polarity)

    # Compute smoothness loss
    resonance_scores_squeezed = tf.squeeze(resonance_scores, axis=-1)
    resonance_diff = resonance_scores_squeezed[:, :, tf.newaxis] - resonance_scores_squeezed[:, tf.newaxis, :]
    squared_diff = tf.square(resonance_diff)
    smoothness_loss = tf.reduce_sum(adjacency * squared_diff, axis=[1,2])
    smoothness_loss = tf.reduce_mean(smoothness_loss)

    # Compute contrastive loss on the features
    contrastive_loss_value = supervised_contrastive_loss(labels_category, features)

    # Total loss
    alpha = 0.1
    beta = 0.1
    total_loss = (weighted_cce_loss_category_mean + weighted_cce_loss_polarity_mean
                  + alpha * smoothness_loss + beta * contrastive_loss_value)

    # Update metrics
    val_accuracy_category.update_state(labels_category, predictions_category)
    val_accuracy_polarity.update_state(labels_polarity, predictions_polarity)

    return total_loss, weighted_cce_loss_category_mean, weighted_cce_loss_polarity_mean, smoothness_loss, contrastive_loss_value

# -------------------------------
# 5. Training the Model
# -------------------------------

epochs = 20
batch_size = 16
alpha = 0.1
beta = 0.1

# Create TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    {
        'input_ids': X_train_ids,
        'attention_masks': X_train_masks,
        'adjacency': adjacency_train
    },
    y_train_category,
    y_train_polarity
)).shuffle(buffer_size=10000).batch(batch_size)

test_dataset = tf.data.Dataset.from_tensor_slices((
    {
        'input_ids': X_test_ids,
        'attention_masks': X_test_masks,
        'adjacency': adjacency_test
    },
    y_test_category,
    y_test_polarity
)).batch(batch_size)



# Import the time module
import time

# Initialize history dictionaries
history = {
    'train_loss': [],
    'train_cce_loss_category': [],
    'train_cce_loss_polarity': [],
    'train_smoothness_loss': [],
    'train_contrastive_loss': [],
    'train_accuracy_category': [],
    'train_accuracy_polarity': [],
    'val_loss': [],
    'val_cce_loss_category': [],
    'val_cce_loss_polarity': [],
    'val_smoothness_loss': [],
    'val_contrastive_loss': [],
    'val_accuracy_category': [],
    'val_accuracy_polarity': [],
    'epoch_time': []  # Added to record time per epoch
}

# Start time of training
training_start_time = time.time()

# Training Loop
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch+1}")
    epoch_start_time = time.time()  # Record start time of the epoch

    # Reset metrics at the start of each epoch
    train_accuracy_category.reset_states()
    train_accuracy_polarity.reset_states()
    val_accuracy_category.reset_states()
    val_accuracy_polarity.reset_states()

    # Training
    total_loss_avg = tf.keras.metrics.Mean()
    cce_loss_category_avg = tf.keras.metrics.Mean()
    cce_loss_polarity_avg = tf.keras.metrics.Mean()
    smoothness_loss_avg = tf.keras.metrics.Mean()
    contrastive_loss_avg = tf.keras.metrics.Mean()

    for step, (batch_inputs, batch_labels_category, batch_labels_polarity) in enumerate(train_dataset):
        input_ids = batch_inputs['input_ids']
        attention_masks = batch_inputs['attention_masks']
        adjacency = batch_inputs['adjacency']
        labels_category = batch_labels_category
        labels_polarity = batch_labels_polarity

        total_loss, cce_loss_cat, cce_loss_pol, smoothness_loss, contrastive_loss_value = train_step(
            input_ids, attention_masks, adjacency, labels_category, labels_polarity)

        total_loss_avg.update_state(total_loss)
        cce_loss_category_avg.update_state(cce_loss_cat)
        cce_loss_polarity_avg.update_state(cce_loss_pol)
        smoothness_loss_avg.update_state(smoothness_loss)
        contrastive_loss_avg.update_state(contrastive_loss_value)

        if step % 100 == 0:
            print(f"Step {step}: Total Loss = {total_loss_avg.result():.4f}, "
                  f"CCE Loss Category = {cce_loss_category_avg.result():.4f}, "
                  f"CCE Loss Polarity = {cce_loss_polarity_avg.result():.4f}, "
                  f"Smoothness Loss = {smoothness_loss_avg.result():.4f}, "
                  f"Contrastive Loss = {contrastive_loss_avg.result():.4f}, "
                  f"Train Accuracy Category = {train_accuracy_category.result():.4f}, "
                  f"Train Accuracy Polarity = {train_accuracy_polarity.result():.4f}")

    # Record training metrics
    history['train_loss'].append(total_loss_avg.result().numpy())
    history['train_cce_loss_category'].append(cce_loss_category_avg.result().numpy())
    history['train_cce_loss_polarity'].append(cce_loss_polarity_avg.result().numpy())
    history['train_smoothness_loss'].append(smoothness_loss_avg.result().numpy())
    history['train_contrastive_loss'].append(contrastive_loss_avg.result().numpy())
    history['train_accuracy_category'].append(train_accuracy_category.result().numpy())
    history['train_accuracy_polarity'].append(train_accuracy_polarity.result().numpy())

    print(f"Epoch {epoch+1} Training Loss: {total_loss_avg.result():.4f}")
    print(f"Epoch {epoch+1} Training CCE Loss Category: {cce_loss_category_avg.result():.4f}")
    print(f"Epoch {epoch+1} Training CCE Loss Polarity: {cce_loss_polarity_avg.result():.4f}")
    print(f"Epoch {epoch+1} Training Smoothness Loss: {smoothness_loss_avg.result():.4f}")
    print(f"Epoch {epoch+1} Training Contrastive Loss: {contrastive_loss_avg.result():.4f}")
    print(f"Epoch {epoch+1} Training Accuracy Category: {train_accuracy_category.result():.4f}")
    print(f"Epoch {epoch+1} Training Accuracy Polarity: {train_accuracy_polarity.result():.4f}")

    # Validation
    val_loss_avg = tf.keras.metrics.Mean()
    val_cce_loss_category_avg = tf.keras.metrics.Mean()
    val_cce_loss_polarity_avg = tf.keras.metrics.Mean()
    val_smoothness_loss_avg = tf.keras.metrics.Mean()
    val_contrastive_loss_avg = tf.keras.metrics.Mean()

    for batch_inputs, batch_labels_category, batch_labels_polarity in test_dataset:
        input_ids = batch_inputs['input_ids']
        attention_masks = batch_inputs['attention_masks']
        adjacency = batch_inputs['adjacency']
        labels_category = batch_labels_category
        labels_polarity = batch_labels_polarity

        total_loss, cce_loss_cat, cce_loss_pol, smoothness_loss, contrastive_loss_value = test_step(
            input_ids, attention_masks, adjacency, labels_category, labels_polarity)

        val_loss_avg.update_state(total_loss)
        val_cce_loss_category_avg.update_state(cce_loss_cat)
        val_cce_loss_polarity_avg.update_state(cce_loss_pol)
        val_smoothness_loss_avg.update_state(smoothness_loss)
        val_contrastive_loss_avg.update_state(contrastive_loss_value)

    # Record validation metrics
    history['val_loss'].append(val_loss_avg.result().numpy())
    history['val_cce_loss_category'].append(val_cce_loss_category_avg.result().numpy())
    history['val_cce_loss_polarity'].append(val_cce_loss_polarity_avg.result().numpy())
    history['val_smoothness_loss'].append(val_smoothness_loss_avg.result().numpy())
    history['val_contrastive_loss'].append(val_contrastive_loss_avg.result().numpy())
    history['val_accuracy_category'].append(val_accuracy_category.result().numpy())
    history['val_accuracy_polarity'].append(val_accuracy_polarity.result().numpy())

    print(f"Epoch {epoch+1} Validation Loss: {val_loss_avg.result():.4f}")
    print(f"Epoch {epoch+1} Validation CCE Loss Category: {val_cce_loss_category_avg.result():.4f}")
    print(f"Epoch {epoch+1} Validation CCE Loss Polarity: {val_cce_loss_polarity_avg.result():.4f}")
    print(f"Epoch {epoch+1} Validation Smoothness Loss: {val_smoothness_loss_avg.result():.4f}")
    print(f"Epoch {epoch+1} Validation Contrastive Loss: {val_contrastive_loss_avg.result():.4f}")
    print(f"Epoch {epoch+1} Validation Accuracy Category: {val_accuracy_category.result():.4f}")
    print(f"Epoch {epoch+1} Validation Accuracy Polarity: {val_accuracy_polarity.result():.4f}")

    # Calculate epoch duration
    epoch_end_time = time.time()
    epoch_duration = epoch_end_time - epoch_start_time
    history['epoch_time'].append(epoch_duration)
    print(f"Epoch {epoch+1} Duration: {epoch_duration:.2f} seconds")

# Total training time
training_end_time = time.time()
total_training_time = training_end_time - training_start_time
print(f"\nTotal Training Time: {total_training_time:.2f} seconds")
# Out:
# Category Class Weights: {0: 0.8531432274789371, 1: 0.7868499701135684, 2: 1.258508604206501, 3: 1.180627802690583, 4: 1.092448132780083}
# Polarity Class Weights: {0: 1.0157407407407408, 1: 1.0009124087591241, 2: 0.9930597465298733, 3: 0.9906682721252258}
#
# Start of epoch 1
# Step 0: Total Loss = 3.5582, CCE Loss Category = 1.5814, CCE Loss Polarity = 1.4074, Smoothness Loss = 2.2235, Contrastive Loss = 3.4695, Train Accuracy Category = 0.1250, Train Accuracy Polarity = 0.3750
# Step 100: Total Loss = 3.1342, CCE Loss Category = 1.5858, CCE Loss Polarity = 1.3948, Smoothness Loss = 0.0559, Contrastive Loss = 1.4799, Train Accuracy Category = 0.2760, Train Accuracy Polarity = 0.3020
# Step 200: Total Loss = 2.8883, CCE Loss Category = 1.4380, CCE Loss Polarity = 1.2689, Smoothness Loss = 0.0312, Contrastive Loss = 1.7835, Train Accuracy Category = 0.3803, Train Accuracy Polarity = 0.3965
# Step 300: Total Loss = 2.6071, CCE Loss Category = 1.2521, CCE Loss Polarity = 1.1468, Smoothness Loss = 0.0237, Contrastive Loss = 2.0574, Train Accuracy Category = 0.4904, Train Accuracy Polarity = 0.4780
# Step 400: Total Loss = 2.3988, CCE Loss Category = 1.1268, CCE Loss Polarity = 1.0470, Smoothness Loss = 0.0189, Contrastive Loss = 2.2305, Train Accuracy Category = 0.5550, Train Accuracy Polarity = 0.5390
# Epoch 1 Training Loss: 2.3787
# Epoch 1 Training CCE Loss Category: 1.1165
# Epoch 1 Training CCE Loss Polarity: 1.0359
# Epoch 1 Training Smoothness Loss: 0.0186
# Epoch 1 Training Contrastive Loss: 2.2433
# Epoch 1 Training Accuracy Category: 0.5606
# Epoch 1 Training Accuracy Polarity: 0.5456
# Epoch 1 Validation Loss: 1.3883
# Epoch 1 Validation CCE Loss Category: 0.5730
# Epoch 1 Validation CCE Loss Polarity: 0.5505
# Epoch 1 Validation Smoothness Loss: 0.0001
# Epoch 1 Validation Contrastive Loss: 2.6473
# Epoch 1 Validation Accuracy Category: 0.8208
# Epoch 1 Validation Accuracy Polarity: 0.8129
# Epoch 1 Duration: 79.41 seconds
#
# Start of epoch 2
# Step 0: Total Loss = 1.4586, CCE Loss Category = 0.6892, CCE Loss Polarity = 0.4972, Smoothness Loss = 0.0086, Contrastive Loss = 2.7129, Train Accuracy Category = 0.7500, Train Accuracy Polarity = 0.8750
# Step 100: Total Loss = 1.3531, CCE Loss Category = 0.5409, CCE Loss Polarity = 0.5155, Smoothness Loss = 0.0054, Contrastive Loss = 2.9621, Train Accuracy Category = 0.8286, Train Accuracy Polarity = 0.8304
# Step 200: Total Loss = 1.2978, CCE Loss Category = 0.5087, CCE Loss Polarity = 0.4958, Smoothness Loss = 0.0043, Contrastive Loss = 2.9284, Train Accuracy Category = 0.8386, Train Accuracy Polarity = 0.8399
# Step 300: Total Loss = 1.2617, CCE Loss Category = 0.5008, CCE Loss Polarity = 0.4683, Smoothness Loss = 0.0036, Contrastive Loss = 2.9225, Train Accuracy Category = 0.8432, Train Accuracy Polarity = 0.8513
# Step 400: Total Loss = 1.2243, CCE Loss Category = 0.4859, CCE Loss Polarity = 0.4485, Smoothness Loss = 0.0033, Contrastive Loss = 2.8953, Train Accuracy Category = 0.8504, Train Accuracy Polarity = 0.8603
# Epoch 2 Training Loss: 1.2223
# Epoch 2 Training CCE Loss Category: 0.4875
# Epoch 2 Training CCE Loss Polarity: 0.4456
# Epoch 2 Training Smoothness Loss: 0.0033
# Epoch 2 Training Contrastive Loss: 2.8889
# Epoch 2 Training Accuracy Category: 0.8502
# Epoch 2 Training Accuracy Polarity: 0.8617
# Epoch 2 Validation Loss: 0.9826
# Epoch 2 Validation CCE Loss Category: 0.3923
# Epoch 2 Validation CCE Loss Polarity: 0.3036
# Epoch 2 Validation Smoothness Loss: 0.0000
# Epoch 2 Validation Contrastive Loss: 2.8667
# Epoch 2 Validation Accuracy Category: 0.8858
# Epoch 2 Validation Accuracy Polarity: 0.9077
# Epoch 2 Duration: 52.36 seconds
#
# Start of epoch 3
# Step 0: Total Loss = 0.7762, CCE Loss Category = 0.2935, CCE Loss Polarity = 0.1798, Smoothness Loss = 0.0021, Contrastive Loss = 3.0279, Train Accuracy Category = 0.8750, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.9061, CCE Loss Category = 0.3247, CCE Loss Polarity = 0.3064, Smoothness Loss = 0.0025, Contrastive Loss = 2.7473, Train Accuracy Category = 0.9127, Train Accuracy Polarity = 0.9177
# Step 200: Total Loss = 0.8949, CCE Loss Category = 0.3295, CCE Loss Polarity = 0.2922, Smoothness Loss = 0.0019, Contrastive Loss = 2.7302, Train Accuracy Category = 0.9104, Train Accuracy Polarity = 0.9263
# Step 300: Total Loss = 0.8871, CCE Loss Category = 0.3375, CCE Loss Polarity = 0.2788, Smoothness Loss = 0.0016, Contrastive Loss = 2.7062, Train Accuracy Category = 0.9043, Train Accuracy Polarity = 0.9298
# Step 400: Total Loss = 0.8704, CCE Loss Category = 0.3358, CCE Loss Polarity = 0.2674, Smoothness Loss = 0.0014, Contrastive Loss = 2.6703, Train Accuracy Category = 0.9046, Train Accuracy Polarity = 0.9342
# Epoch 3 Training Loss: 0.8740
# Epoch 3 Training CCE Loss Category: 0.3397
# Epoch 3 Training CCE Loss Polarity: 0.2671
# Epoch 3 Training Smoothness Loss: 0.0014
# Epoch 3 Training Contrastive Loss: 2.6710
# Epoch 3 Training Accuracy Category: 0.9026
# Epoch 3 Training Accuracy Polarity: 0.9342
# Epoch 3 Validation Loss: 0.7763
# Epoch 3 Validation CCE Loss Category: 0.3170
# Epoch 3 Validation CCE Loss Polarity: 0.1953
# Epoch 3 Validation Smoothness Loss: 0.0000
# Epoch 3 Validation Contrastive Loss: 2.6397
# Epoch 3 Validation Accuracy Category: 0.9101
# Epoch 3 Validation Accuracy Polarity: 0.9496
# Epoch 3 Duration: 52.09 seconds
#
# Start of epoch 4
# Step 0: Total Loss = 0.6425, CCE Loss Category = 0.1680, CCE Loss Polarity = 0.2263, Smoothness Loss = 0.0009, Contrastive Loss = 2.4806, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.7566, CCE Loss Category = 0.2892, CCE Loss Polarity = 0.2176, Smoothness Loss = 0.0010, Contrastive Loss = 2.4972, Train Accuracy Category = 0.9134, Train Accuracy Polarity = 0.9524
# Step 200: Total Loss = 0.7557, CCE Loss Category = 0.2939, CCE Loss Polarity = 0.2129, Smoothness Loss = 0.0009, Contrastive Loss = 2.4881, Train Accuracy Category = 0.9098, Train Accuracy Polarity = 0.9496
# Step 300: Total Loss = 0.7440, CCE Loss Category = 0.2961, CCE Loss Polarity = 0.2012, Smoothness Loss = 0.0008, Contrastive Loss = 2.4666, Train Accuracy Category = 0.9093, Train Accuracy Polarity = 0.9549
# Step 400: Total Loss = 0.7288, CCE Loss Category = 0.2888, CCE Loss Polarity = 0.1968, Smoothness Loss = 0.0008, Contrastive Loss = 2.4308, Train Accuracy Category = 0.9115, Train Accuracy Polarity = 0.9557
# Epoch 4 Training Loss: 0.7271
# Epoch 4 Training CCE Loss Category: 0.2883
# Epoch 4 Training CCE Loss Polarity: 0.1963
# Epoch 4 Training Smoothness Loss: 0.0008
# Epoch 4 Training Contrastive Loss: 2.4242
# Epoch 4 Training Accuracy Category: 0.9119
# Epoch 4 Training Accuracy Polarity: 0.9562
# Epoch 4 Validation Loss: 0.6818
# Epoch 4 Validation CCE Loss Category: 0.2782
# Epoch 4 Validation CCE Loss Polarity: 0.1632
# Epoch 4 Validation Smoothness Loss: 0.0000
# Epoch 4 Validation Contrastive Loss: 2.4037
# Epoch 4 Validation Accuracy Category: 0.9143
# Epoch 4 Validation Accuracy Polarity: 0.9623
# Epoch 4 Duration: 52.12 seconds
#
# Start of epoch 5
# Step 0: Total Loss = 0.6874, CCE Loss Category = 0.2685, CCE Loss Polarity = 0.1567, Smoothness Loss = 0.0010, Contrastive Loss = 2.6208, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.6102, CCE Loss Category = 0.2281, CCE Loss Polarity = 0.1487, Smoothness Loss = 0.0008, Contrastive Loss = 2.3320, Train Accuracy Category = 0.9325, Train Accuracy Polarity = 0.9715
# Step 200: Total Loss = 0.6478, CCE Loss Category = 0.2533, CCE Loss Polarity = 0.1630, Smoothness Loss = 0.0006, Contrastive Loss = 2.3139, Train Accuracy Category = 0.9235, Train Accuracy Polarity = 0.9646
# Step 300: Total Loss = 0.6438, CCE Loss Category = 0.2537, CCE Loss Polarity = 0.1589, Smoothness Loss = 0.0005, Contrastive Loss = 2.3112, Train Accuracy Category = 0.9203, Train Accuracy Polarity = 0.9645
# Step 400: Total Loss = 0.6553, CCE Loss Category = 0.2634, CCE Loss Polarity = 0.1634, Smoothness Loss = 0.0005, Contrastive Loss = 2.2847, Train Accuracy Category = 0.9168, Train Accuracy Polarity = 0.9631
# Epoch 5 Training Loss: 0.6560
# Epoch 5 Training CCE Loss Category: 0.2655
# Epoch 5 Training CCE Loss Polarity: 0.1626
# Epoch 5 Training Smoothness Loss: 0.0005
# Epoch 5 Training Contrastive Loss: 2.2787
# Epoch 5 Training Accuracy Category: 0.9152
# Epoch 5 Training Accuracy Polarity: 0.9629
# Epoch 5 Validation Loss: 0.6418
# Epoch 5 Validation CCE Loss Category: 0.2743
# Epoch 5 Validation CCE Loss Polarity: 0.1444
# Epoch 5 Validation Smoothness Loss: 0.0000
# Epoch 5 Validation Contrastive Loss: 2.2310
# Epoch 5 Validation Accuracy Category: 0.9113
# Epoch 5 Validation Accuracy Polarity: 0.9599
# Epoch 5 Duration: 52.60 seconds
#
# Start of epoch 6
# Step 0: Total Loss = 0.4105, CCE Loss Category = 0.1320, CCE Loss Polarity = 0.0872, Smoothness Loss = 0.0006, Contrastive Loss = 1.9129, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.6049, CCE Loss Category = 0.2367, CCE Loss Polarity = 0.1486, Smoothness Loss = 0.0005, Contrastive Loss = 2.1961, Train Accuracy Category = 0.9208, Train Accuracy Polarity = 0.9647
# Step 200: Total Loss = 0.6017, CCE Loss Category = 0.2430, CCE Loss Polarity = 0.1415, Smoothness Loss = 0.0004, Contrastive Loss = 2.1714, Train Accuracy Category = 0.9223, Train Accuracy Polarity = 0.9686
# Step 300: Total Loss = 0.6025, CCE Loss Category = 0.2443, CCE Loss Polarity = 0.1425, Smoothness Loss = 0.0004, Contrastive Loss = 2.1566, Train Accuracy Category = 0.9205, Train Accuracy Polarity = 0.9668
# Step 400: Total Loss = 0.5927, CCE Loss Category = 0.2411, CCE Loss Polarity = 0.1378, Smoothness Loss = 0.0004, Contrastive Loss = 2.1376, Train Accuracy Category = 0.9200, Train Accuracy Polarity = 0.9665
# Epoch 6 Training Loss: 0.5951
# Epoch 6 Training CCE Loss Category: 0.2419
# Epoch 6 Training CCE Loss Polarity: 0.1396
# Epoch 6 Training Smoothness Loss: 0.0004
# Epoch 6 Training Contrastive Loss: 2.1353
# Epoch 6 Training Accuracy Category: 0.9193
# Epoch 6 Training Accuracy Polarity: 0.9661
# Epoch 6 Validation Loss: 0.6151
# Epoch 6 Validation CCE Loss Category: 0.2683
# Epoch 6 Validation CCE Loss Polarity: 0.1372
# Epoch 6 Validation Smoothness Loss: 0.0000
# Epoch 6 Validation Contrastive Loss: 2.0964
# Epoch 6 Validation Accuracy Category: 0.9210
# Epoch 6 Validation Accuracy Polarity: 0.9642
# Epoch 6 Duration: 52.56 seconds
#
# Start of epoch 7
# Step 0: Total Loss = 0.3057, CCE Loss Category = 0.0447, CCE Loss Polarity = 0.0557, Smoothness Loss = 0.0001, Contrastive Loss = 2.0530, Train Accuracy Category = 1.0000, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.5677, CCE Loss Category = 0.2239, CCE Loss Polarity = 0.1380, Smoothness Loss = 0.0004, Contrastive Loss = 2.0567, Train Accuracy Category = 0.9233, Train Accuracy Polarity = 0.9722
# Step 200: Total Loss = 0.5623, CCE Loss Category = 0.2273, CCE Loss Polarity = 0.1284, Smoothness Loss = 0.0004, Contrastive Loss = 2.0647, Train Accuracy Category = 0.9241, Train Accuracy Polarity = 0.9705
# Step 300: Total Loss = 0.5548, CCE Loss Category = 0.2257, CCE Loss Polarity = 0.1249, Smoothness Loss = 0.0004, Contrastive Loss = 2.0417, Train Accuracy Category = 0.9246, Train Accuracy Polarity = 0.9707
# Step 400: Total Loss = 0.5531, CCE Loss Category = 0.2246, CCE Loss Polarity = 0.1245, Smoothness Loss = 0.0004, Contrastive Loss = 2.0402, Train Accuracy Category = 0.9258, Train Accuracy Polarity = 0.9712
# Epoch 7 Training Loss: 0.5517
# Epoch 7 Training CCE Loss Category: 0.2239
# Epoch 7 Training CCE Loss Polarity: 0.1238
# Epoch 7 Training Smoothness Loss: 0.0004
# Epoch 7 Training Contrastive Loss: 2.0395
# Epoch 7 Training Accuracy Category: 0.9256
# Epoch 7 Training Accuracy Polarity: 0.9711
# Epoch 7 Validation Loss: 0.5977
# Epoch 7 Validation CCE Loss Category: 0.2721
# Epoch 7 Validation CCE Loss Polarity: 0.1253
# Epoch 7 Validation Smoothness Loss: 0.0000
# Epoch 7 Validation Contrastive Loss: 2.0031
# Epoch 7 Validation Accuracy Category: 0.9137
# Epoch 7 Validation Accuracy Polarity: 0.9629
# Epoch 7 Duration: 52.39 seconds
#
# Start of epoch 8
# Step 0: Total Loss = 0.8346, CCE Loss Category = 0.5375, CCE Loss Polarity = 0.1023, Smoothness Loss = 0.0000, Contrastive Loss = 1.9481, Train Accuracy Category = 0.8125, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.4815, CCE Loss Category = 0.1795, CCE Loss Polarity = 0.1074, Smoothness Loss = 0.0004, Contrastive Loss = 1.9454, Train Accuracy Category = 0.9425, Train Accuracy Polarity = 0.9734
# Step 200: Total Loss = 0.5045, CCE Loss Category = 0.2001, CCE Loss Polarity = 0.1082, Smoothness Loss = 0.0003, Contrastive Loss = 1.9623, Train Accuracy Category = 0.9359, Train Accuracy Polarity = 0.9714
# Step 300: Total Loss = 0.5171, CCE Loss Category = 0.2112, CCE Loss Polarity = 0.1118, Smoothness Loss = 0.0003, Contrastive Loss = 1.9411, Train Accuracy Category = 0.9315, Train Accuracy Polarity = 0.9709
# Step 400: Total Loss = 0.5198, CCE Loss Category = 0.2153, CCE Loss Polarity = 0.1106, Smoothness Loss = 0.0003, Contrastive Loss = 1.9389, Train Accuracy Category = 0.9291, Train Accuracy Polarity = 0.9705
# Epoch 8 Training Loss: 0.5191
# Epoch 8 Training CCE Loss Category: 0.2149
# Epoch 8 Training CCE Loss Polarity: 0.1105
# Epoch 8 Training Smoothness Loss: 0.0003
# Epoch 8 Training Contrastive Loss: 1.9367
# Epoch 8 Training Accuracy Category: 0.9292
# Epoch 8 Training Accuracy Polarity: 0.9707
# Epoch 8 Validation Loss: 0.6483
# Epoch 8 Validation CCE Loss Category: 0.3068
# Epoch 8 Validation CCE Loss Polarity: 0.1475
# Epoch 8 Validation Smoothness Loss: 0.0000
# Epoch 8 Validation Contrastive Loss: 1.9396
# Epoch 8 Validation Accuracy Category: 0.9131
# Epoch 8 Validation Accuracy Polarity: 0.9599
# Epoch 8 Duration: 52.42 seconds
#
# Start of epoch 9
# Step 0: Total Loss = 0.4492, CCE Loss Category = 0.1179, CCE Loss Polarity = 0.1334, Smoothness Loss = 0.0004, Contrastive Loss = 1.9784, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.4933, CCE Loss Category = 0.1875, CCE Loss Polarity = 0.1137, Smoothness Loss = 0.0006, Contrastive Loss = 1.9206, Train Accuracy Category = 0.9313, Train Accuracy Polarity = 0.9653
# Step 200: Total Loss = 0.4974, CCE Loss Category = 0.1969, CCE Loss Polarity = 0.1105, Smoothness Loss = 0.0005, Contrastive Loss = 1.8992, Train Accuracy Category = 0.9282, Train Accuracy Polarity = 0.9686
# Step 300: Total Loss = 0.5084, CCE Loss Category = 0.2101, CCE Loss Polarity = 0.1088, Smoothness Loss = 0.0004, Contrastive Loss = 1.8944, Train Accuracy Category = 0.9238, Train Accuracy Polarity = 0.9697
# Step 400: Total Loss = 0.5046, CCE Loss Category = 0.2073, CCE Loss Polarity = 0.1092, Smoothness Loss = 0.0004, Contrastive Loss = 1.8800, Train Accuracy Category = 0.9263, Train Accuracy Polarity = 0.9704
# Epoch 9 Training Loss: 0.5045
# Epoch 9 Training CCE Loss Category: 0.2070
# Epoch 9 Training CCE Loss Polarity: 0.1095
# Epoch 9 Training Smoothness Loss: 0.0004
# Epoch 9 Training Contrastive Loss: 1.8797
# Epoch 9 Training Accuracy Category: 0.9260
# Epoch 9 Training Accuracy Polarity: 0.9701
# Epoch 9 Validation Loss: 0.5868
# Epoch 9 Validation CCE Loss Category: 0.2831
# Epoch 9 Validation CCE Loss Polarity: 0.1097
# Epoch 9 Validation Smoothness Loss: 0.0000
# Epoch 9 Validation Contrastive Loss: 1.9402
# Epoch 9 Validation Accuracy Category: 0.9131
# Epoch 9 Validation Accuracy Polarity: 0.9696
# Epoch 9 Duration: 52.20 seconds
#
# Start of epoch 10
# Step 0: Total Loss = 0.4647, CCE Loss Category = 0.1850, CCE Loss Polarity = 0.0970, Smoothness Loss = 0.0005, Contrastive Loss = 1.8263, Train Accuracy Category = 0.8750, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.5134, CCE Loss Category = 0.2098, CCE Loss Polarity = 0.1176, Smoothness Loss = 0.0002, Contrastive Loss = 1.8594, Train Accuracy Category = 0.9239, Train Accuracy Polarity = 0.9653
# Step 200: Total Loss = 0.4796, CCE Loss Category = 0.1972, CCE Loss Polarity = 0.0977, Smoothness Loss = 0.0002, Contrastive Loss = 1.8472, Train Accuracy Category = 0.9288, Train Accuracy Polarity = 0.9733
# Step 300: Total Loss = 0.4876, CCE Loss Category = 0.1994, CCE Loss Polarity = 0.1042, Smoothness Loss = 0.0002, Contrastive Loss = 1.8395, Train Accuracy Category = 0.9286, Train Accuracy Polarity = 0.9720
# Step 400: Total Loss = 0.4954, CCE Loss Category = 0.2069, CCE Loss Polarity = 0.1056, Smoothness Loss = 0.0002, Contrastive Loss = 1.8292, Train Accuracy Category = 0.9272, Train Accuracy Polarity = 0.9713
# Epoch 10 Training Loss: 0.5010
# Epoch 10 Training CCE Loss Category: 0.2086
# Epoch 10 Training CCE Loss Polarity: 0.1096
# Epoch 10 Training Smoothness Loss: 0.0002
# Epoch 10 Training Contrastive Loss: 1.8280
# Epoch 10 Training Accuracy Category: 0.9268
# Epoch 10 Training Accuracy Polarity: 0.9699
# Epoch 10 Validation Loss: 0.5851
# Epoch 10 Validation CCE Loss Category: 0.2501
# Epoch 10 Validation CCE Loss Polarity: 0.1579
# Epoch 10 Validation Smoothness Loss: 0.0000
# Epoch 10 Validation Contrastive Loss: 1.7710
# Epoch 10 Validation Accuracy Category: 0.9192
# Epoch 10 Validation Accuracy Polarity: 0.9526
# Epoch 10 Duration: 52.24 seconds
#
# Start of epoch 11
# Step 0: Total Loss = 0.3198, CCE Loss Category = 0.0495, CCE Loss Polarity = 0.1109, Smoothness Loss = 0.0002, Contrastive Loss = 1.5949, Train Accuracy Category = 1.0000, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.5373, CCE Loss Category = 0.2216, CCE Loss Polarity = 0.1363, Smoothness Loss = 0.0002, Contrastive Loss = 1.7941, Train Accuracy Category = 0.9115, Train Accuracy Polarity = 0.9592
# Step 200: Total Loss = 0.5367, CCE Loss Category = 0.2257, CCE Loss Polarity = 0.1303, Smoothness Loss = 0.0002, Contrastive Loss = 1.8070, Train Accuracy Category = 0.9117, Train Accuracy Polarity = 0.9605
# Step 300: Total Loss = 0.5240, CCE Loss Category = 0.2185, CCE Loss Polarity = 0.1249, Smoothness Loss = 0.0002, Contrastive Loss = 1.8048, Train Accuracy Category = 0.9161, Train Accuracy Polarity = 0.9630
# Step 400: Total Loss = 0.5142, CCE Loss Category = 0.2127, CCE Loss Polarity = 0.1220, Smoothness Loss = 0.0002, Contrastive Loss = 1.7951, Train Accuracy Category = 0.9196, Train Accuracy Polarity = 0.9642
# Epoch 11 Training Loss: 0.5162
# Epoch 11 Training CCE Loss Category: 0.2137
# Epoch 11 Training CCE Loss Polarity: 0.1233
# Epoch 11 Training Smoothness Loss: 0.0002
# Epoch 11 Training Contrastive Loss: 1.7918
# Epoch 11 Training Accuracy Category: 0.9186
# Epoch 11 Training Accuracy Polarity: 0.9640
# Epoch 11 Validation Loss: 0.5661
# Epoch 11 Validation CCE Loss Category: 0.2642
# Epoch 11 Validation CCE Loss Polarity: 0.1280
# Epoch 11 Validation Smoothness Loss: 0.0000
# Epoch 11 Validation Contrastive Loss: 1.7388
# Epoch 11 Validation Accuracy Category: 0.9046
# Epoch 11 Validation Accuracy Polarity: 0.9660
# Epoch 11 Duration: 53.23 seconds
#
# Start of epoch 12
# Step 0: Total Loss = 0.4051, CCE Loss Category = 0.1980, CCE Loss Polarity = 0.0366, Smoothness Loss = 0.0001, Contrastive Loss = 1.7049, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.4570, CCE Loss Category = 0.1923, CCE Loss Polarity = 0.0885, Smoothness Loss = 0.0002, Contrastive Loss = 1.7622, Train Accuracy Category = 0.9270, Train Accuracy Polarity = 0.9734
# Step 200: Total Loss = 0.4727, CCE Loss Category = 0.2003, CCE Loss Polarity = 0.0949, Smoothness Loss = 0.0002, Contrastive Loss = 1.7739, Train Accuracy Category = 0.9248, Train Accuracy Polarity = 0.9701
# Step 300: Total Loss = 0.4706, CCE Loss Category = 0.1980, CCE Loss Polarity = 0.0959, Smoothness Loss = 0.0002, Contrastive Loss = 1.7661, Train Accuracy Category = 0.9257, Train Accuracy Polarity = 0.9705
# Step 400: Total Loss = 0.4797, CCE Loss Category = 0.2018, CCE Loss Polarity = 0.1022, Smoothness Loss = 0.0002, Contrastive Loss = 1.7570, Train Accuracy Category = 0.9250, Train Accuracy Polarity = 0.9679
# Epoch 12 Training Loss: 0.4791
# Epoch 12 Training CCE Loss Category: 0.2014
# Epoch 12 Training CCE Loss Polarity: 0.1023
# Epoch 12 Training Smoothness Loss: 0.0002
# Epoch 12 Training Contrastive Loss: 1.7540
# Epoch 12 Training Accuracy Category: 0.9251
# Epoch 12 Training Accuracy Polarity: 0.9678
# Epoch 12 Validation Loss: 0.5673
# Epoch 12 Validation CCE Loss Category: 0.2553
# Epoch 12 Validation CCE Loss Polarity: 0.1356
# Epoch 12 Validation Smoothness Loss: 0.0000
# Epoch 12 Validation Contrastive Loss: 1.7643
# Epoch 12 Validation Accuracy Category: 0.9235
# Epoch 12 Validation Accuracy Polarity: 0.9611
# Epoch 12 Duration: 53.53 seconds
#
# Start of epoch 13
# Step 0: Total Loss = 0.4523, CCE Loss Category = 0.1440, CCE Loss Polarity = 0.1478, Smoothness Loss = 0.0000, Contrastive Loss = 1.6042, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.4469, CCE Loss Category = 0.1887, CCE Loss Polarity = 0.0832, Smoothness Loss = 0.0002, Contrastive Loss = 1.7500, Train Accuracy Category = 0.9264, Train Accuracy Polarity = 0.9752
# Step 200: Total Loss = 0.4676, CCE Loss Category = 0.1968, CCE Loss Polarity = 0.0965, Smoothness Loss = 0.0002, Contrastive Loss = 1.7432, Train Accuracy Category = 0.9229, Train Accuracy Polarity = 0.9708
# Step 300: Total Loss = 0.4571, CCE Loss Category = 0.1906, CCE Loss Polarity = 0.0935, Smoothness Loss = 0.0001, Contrastive Loss = 1.7310, Train Accuracy Category = 0.9255, Train Accuracy Polarity = 0.9709
# Step 400: Total Loss = 0.4508, CCE Loss Category = 0.1888, CCE Loss Polarity = 0.0897, Smoothness Loss = 0.0001, Contrastive Loss = 1.7239, Train Accuracy Category = 0.9261, Train Accuracy Polarity = 0.9732
# Epoch 13 Training Loss: 0.4475
# Epoch 13 Training CCE Loss Category: 0.1868
# Epoch 13 Training CCE Loss Polarity: 0.0885
# Epoch 13 Training Smoothness Loss: 0.0001
# Epoch 13 Training Contrastive Loss: 1.7231
# Epoch 13 Training Accuracy Category: 0.9271
# Epoch 13 Training Accuracy Polarity: 0.9739
# Epoch 13 Validation Loss: 0.5368
# Epoch 13 Validation CCE Loss Category: 0.2426
# Epoch 13 Validation CCE Loss Polarity: 0.1165
# Epoch 13 Validation Smoothness Loss: 0.0000
# Epoch 13 Validation Contrastive Loss: 1.7766
# Epoch 13 Validation Accuracy Category: 0.9241
# Epoch 13 Validation Accuracy Polarity: 0.9635
# Epoch 13 Duration: 53.39 seconds
#
# Start of epoch 14
# Step 0: Total Loss = 0.3934, CCE Loss Category = 0.2009, CCE Loss Polarity = 0.0181, Smoothness Loss = 0.0001, Contrastive Loss = 1.7449, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.4361, CCE Loss Category = 0.1723, CCE Loss Polarity = 0.0926, Smoothness Loss = 0.0001, Contrastive Loss = 1.7122, Train Accuracy Category = 0.9369, Train Accuracy Polarity = 0.9660
# Step 200: Total Loss = 0.4641, CCE Loss Category = 0.1929, CCE Loss Polarity = 0.1001, Smoothness Loss = 0.0001, Contrastive Loss = 1.7103, Train Accuracy Category = 0.9275, Train Accuracy Polarity = 0.9670
# Step 300: Total Loss = 0.4731, CCE Loss Category = 0.1974, CCE Loss Polarity = 0.1049, Smoothness Loss = 0.0001, Contrastive Loss = 1.7078, Train Accuracy Category = 0.9255, Train Accuracy Polarity = 0.9678
# Step 400: Total Loss = 0.4668, CCE Loss Category = 0.1947, CCE Loss Polarity = 0.1013, Smoothness Loss = 0.0001, Contrastive Loss = 1.7086, Train Accuracy Category = 0.9263, Train Accuracy Polarity = 0.9685
# Epoch 14 Training Loss: 0.4693
# Epoch 14 Training CCE Loss Category: 0.1971
# Epoch 14 Training CCE Loss Polarity: 0.1018
# Epoch 14 Training Smoothness Loss: 0.0001
# Epoch 14 Training Contrastive Loss: 1.7041
# Epoch 14 Training Accuracy Category: 0.9256
# Epoch 14 Training Accuracy Polarity: 0.9679
# Epoch 14 Validation Loss: 0.5418
# Epoch 14 Validation CCE Loss Category: 0.2580
# Epoch 14 Validation CCE Loss Polarity: 0.1156
# Epoch 14 Validation Smoothness Loss: 0.0000
# Epoch 14 Validation Contrastive Loss: 1.6822
# Epoch 14 Validation Accuracy Category: 0.9192
# Epoch 14 Validation Accuracy Polarity: 0.9654
# Epoch 14 Duration: 53.40 seconds
#
# Start of epoch 15
# Step 0: Total Loss = 0.4507, CCE Loss Category = 0.0209, CCE Loss Polarity = 0.2137, Smoothness Loss = 0.0000, Contrastive Loss = 2.1609, Train Accuracy Category = 1.0000, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.4809, CCE Loss Category = 0.2023, CCE Loss Polarity = 0.1102, Smoothness Loss = 0.0001, Contrastive Loss = 1.6841, Train Accuracy Category = 0.9134, Train Accuracy Polarity = 0.9623
# Step 200: Total Loss = 0.4432, CCE Loss Category = 0.1801, CCE Loss Polarity = 0.0960, Smoothness Loss = 0.0001, Contrastive Loss = 1.6715, Train Accuracy Category = 0.9235, Train Accuracy Polarity = 0.9686
# Step 300: Total Loss = 0.4404, CCE Loss Category = 0.1801, CCE Loss Polarity = 0.0932, Smoothness Loss = 0.0001, Contrastive Loss = 1.6705, Train Accuracy Category = 0.9273, Train Accuracy Polarity = 0.9711
# Step 400: Total Loss = 0.4402, CCE Loss Category = 0.1815, CCE Loss Polarity = 0.0920, Smoothness Loss = 0.0001, Contrastive Loss = 1.6668, Train Accuracy Category = 0.9253, Train Accuracy Polarity = 0.9699
# Epoch 15 Training Loss: 0.4403
# Epoch 15 Training CCE Loss Category: 0.1826
# Epoch 15 Training CCE Loss Polarity: 0.0913
# Epoch 15 Training Smoothness Loss: 0.0001
# Epoch 15 Training Contrastive Loss: 1.6632
# Epoch 15 Training Accuracy Category: 0.9259
# Epoch 15 Training Accuracy Polarity: 0.9704
# Epoch 15 Validation Loss: 0.5465
# Epoch 15 Validation CCE Loss Category: 0.2604
# Epoch 15 Validation CCE Loss Polarity: 0.1181
# Epoch 15 Validation Smoothness Loss: 0.0000
# Epoch 15 Validation Contrastive Loss: 1.6809
# Epoch 15 Validation Accuracy Category: 0.9180
# Epoch 15 Validation Accuracy Polarity: 0.9666
# Epoch 15 Duration: 53.63 seconds
#
# Start of epoch 16
# Step 0: Total Loss = 0.2704, CCE Loss Category = 0.0792, CCE Loss Polarity = 0.0272, Smoothness Loss = 0.0001, Contrastive Loss = 1.6403, Train Accuracy Category = 1.0000, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.4181, CCE Loss Category = 0.1749, CCE Loss Polarity = 0.0769, Smoothness Loss = 0.0001, Contrastive Loss = 1.6625, Train Accuracy Category = 0.9245, Train Accuracy Polarity = 0.9765
# Step 200: Total Loss = 0.4263, CCE Loss Category = 0.1740, CCE Loss Polarity = 0.0866, Smoothness Loss = 0.0001, Contrastive Loss = 1.6562, Train Accuracy Category = 0.9257, Train Accuracy Polarity = 0.9711
# Step 300: Total Loss = 0.4260, CCE Loss Category = 0.1765, CCE Loss Polarity = 0.0831, Smoothness Loss = 0.0001, Contrastive Loss = 1.6632, Train Accuracy Category = 0.9265, Train Accuracy Polarity = 0.9726
# Step 400: Total Loss = 0.4269, CCE Loss Category = 0.1782, CCE Loss Polarity = 0.0828, Smoothness Loss = 0.0001, Contrastive Loss = 1.6595, Train Accuracy Category = 0.9274, Train Accuracy Polarity = 0.9726
# Epoch 16 Training Loss: 0.4291
# Epoch 16 Training CCE Loss Category: 0.1803
# Epoch 16 Training CCE Loss Polarity: 0.0829
# Epoch 16 Training Smoothness Loss: 0.0001
# Epoch 16 Training Contrastive Loss: 1.6592
# Epoch 16 Training Accuracy Category: 0.9266
# Epoch 16 Training Accuracy Polarity: 0.9730
# Epoch 16 Validation Loss: 0.5527
# Epoch 16 Validation CCE Loss Category: 0.2729
# Epoch 16 Validation CCE Loss Polarity: 0.1122
# Epoch 16 Validation Smoothness Loss: 0.0000
# Epoch 16 Validation Contrastive Loss: 1.6769
# Epoch 16 Validation Accuracy Category: 0.9216
# Epoch 16 Validation Accuracy Polarity: 0.9648
# Epoch 16 Duration: 56.02 seconds
#
# Start of epoch 17
# Step 0: Total Loss = 0.3086, CCE Loss Category = 0.1169, CCE Loss Polarity = 0.0321, Smoothness Loss = 0.0000, Contrastive Loss = 1.5958, Train Accuracy Category = 1.0000, Train Accuracy Polarity = 1.0000
# Step 100: Total Loss = 0.4040, CCE Loss Category = 0.1664, CCE Loss Polarity = 0.0766, Smoothness Loss = 0.0001, Contrastive Loss = 1.6094, Train Accuracy Category = 0.9295, Train Accuracy Polarity = 0.9709
# Step 200: Total Loss = 0.4179, CCE Loss Category = 0.1698, CCE Loss Polarity = 0.0869, Smoothness Loss = 0.0001, Contrastive Loss = 1.6115, Train Accuracy Category = 0.9282, Train Accuracy Polarity = 0.9695
# Step 300: Total Loss = 0.4213, CCE Loss Category = 0.1738, CCE Loss Polarity = 0.0856, Smoothness Loss = 0.0000, Contrastive Loss = 1.6186, Train Accuracy Category = 0.9265, Train Accuracy Polarity = 0.9716
# Step 400: Total Loss = 0.4182, CCE Loss Category = 0.1728, CCE Loss Polarity = 0.0831, Smoothness Loss = 0.0001, Contrastive Loss = 1.6230, Train Accuracy Category = 0.9277, Train Accuracy Polarity = 0.9735
# Epoch 17 Training Loss: 0.4186
# Epoch 17 Training CCE Loss Category: 0.1730
# Epoch 17 Training CCE Loss Polarity: 0.0833
# Epoch 17 Training Smoothness Loss: 0.0001
# Epoch 17 Training Contrastive Loss: 1.6231
# Epoch 17 Training Accuracy Category: 0.9278
# Epoch 17 Training Accuracy Polarity: 0.9736
# Epoch 17 Validation Loss: 0.5602
# Epoch 17 Validation CCE Loss Category: 0.2758
# Epoch 17 Validation CCE Loss Polarity: 0.1161
# Epoch 17 Validation Smoothness Loss: 0.0000
# Epoch 17 Validation Contrastive Loss: 1.6823
# Epoch 17 Validation Accuracy Category: 0.9058
# Epoch 17 Validation Accuracy Polarity: 0.9605
# Epoch 17 Duration: 55.38 seconds
#
# Start of epoch 18
# Step 0: Total Loss = 0.5063, CCE Loss Category = 0.2062, CCE Loss Polarity = 0.1346, Smoothness Loss = 0.0000, Contrastive Loss = 1.6550, Train Accuracy Category = 0.9375, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.4173, CCE Loss Category = 0.1618, CCE Loss Polarity = 0.0946, Smoothness Loss = 0.0001, Contrastive Loss = 1.6089, Train Accuracy Category = 0.9313, Train Accuracy Polarity = 0.9653
# Step 200: Total Loss = 0.4186, CCE Loss Category = 0.1697, CCE Loss Polarity = 0.0867, Smoothness Loss = 0.0001, Contrastive Loss = 1.6211, Train Accuracy Category = 0.9294, Train Accuracy Polarity = 0.9692
# Step 300: Total Loss = 0.4218, CCE Loss Category = 0.1778, CCE Loss Polarity = 0.0825, Smoothness Loss = 0.0001, Contrastive Loss = 1.6149, Train Accuracy Category = 0.9257, Train Accuracy Polarity = 0.9716
# Step 400: Total Loss = 0.4151, CCE Loss Category = 0.1743, CCE Loss Polarity = 0.0801, Smoothness Loss = 0.0001, Contrastive Loss = 1.6063, Train Accuracy Category = 0.9278, Train Accuracy Polarity = 0.9727
# Epoch 18 Training Loss: 0.4174
# Epoch 18 Training CCE Loss Category: 0.1761
# Epoch 18 Training CCE Loss Polarity: 0.0808
# Epoch 18 Training Smoothness Loss: 0.0001
# Epoch 18 Training Contrastive Loss: 1.6043
# Epoch 18 Training Accuracy Category: 0.9274
# Epoch 18 Training Accuracy Polarity: 0.9722
# Epoch 18 Validation Loss: 0.5252
# Epoch 18 Validation CCE Loss Category: 0.2528
# Epoch 18 Validation CCE Loss Polarity: 0.1117
# Epoch 18 Validation Smoothness Loss: 0.0000
# Epoch 18 Validation Contrastive Loss: 1.6068
# Epoch 18 Validation Accuracy Category: 0.9113
# Epoch 18 Validation Accuracy Polarity: 0.9635
# Epoch 18 Duration: 62.11 seconds
#
# Start of epoch 19
# Step 0: Total Loss = 0.2728, CCE Loss Category = 0.0447, CCE Loss Polarity = 0.0868, Smoothness Loss = 0.0000, Contrastive Loss = 1.4131, Train Accuracy Category = 1.0000, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.3984, CCE Loss Category = 0.1585, CCE Loss Polarity = 0.0815, Smoothness Loss = 0.0000, Contrastive Loss = 1.5835, Train Accuracy Category = 0.9332, Train Accuracy Polarity = 0.9697
# Step 200: Total Loss = 0.4008, CCE Loss Category = 0.1610, CCE Loss Polarity = 0.0807, Smoothness Loss = 0.0000, Contrastive Loss = 1.5907, Train Accuracy Category = 0.9316, Train Accuracy Polarity = 0.9717
# Step 300: Total Loss = 0.4089, CCE Loss Category = 0.1693, CCE Loss Polarity = 0.0804, Smoothness Loss = 0.0000, Contrastive Loss = 1.5924, Train Accuracy Category = 0.9302, Train Accuracy Polarity = 0.9720
# Step 400: Total Loss = 0.4079, CCE Loss Category = 0.1692, CCE Loss Polarity = 0.0796, Smoothness Loss = 0.0000, Contrastive Loss = 1.5905, Train Accuracy Category = 0.9296, Train Accuracy Polarity = 0.9723
# Epoch 19 Training Loss: 0.4080
# Epoch 19 Training CCE Loss Category: 0.1697
# Epoch 19 Training CCE Loss Polarity: 0.0796
# Epoch 19 Training Smoothness Loss: 0.0000
# Epoch 19 Training Contrastive Loss: 1.5863
# Epoch 19 Training Accuracy Category: 0.9294
# Epoch 19 Training Accuracy Polarity: 0.9725
# Epoch 19 Validation Loss: 0.5389
# Epoch 19 Validation CCE Loss Category: 0.2648
# Epoch 19 Validation CCE Loss Polarity: 0.1128
# Epoch 19 Validation Smoothness Loss: 0.0000
# Epoch 19 Validation Contrastive Loss: 1.6131
# Epoch 19 Validation Accuracy Category: 0.9089
# Epoch 19 Validation Accuracy Polarity: 0.9678
# Epoch 19 Duration: 61.95 seconds
#
# Start of epoch 20
# Step 0: Total Loss = 0.6565, CCE Loss Category = 0.2438, CCE Loss Polarity = 0.2538, Smoothness Loss = 0.0000, Contrastive Loss = 1.5895, Train Accuracy Category = 0.8125, Train Accuracy Polarity = 0.9375
# Step 100: Total Loss = 0.4369, CCE Loss Category = 0.1711, CCE Loss Polarity = 0.1096, Smoothness Loss = 0.0000, Contrastive Loss = 1.5622, Train Accuracy Category = 0.9226, Train Accuracy Polarity = 0.9666
# Step 200: Total Loss = 0.4214, CCE Loss Category = 0.1716, CCE Loss Polarity = 0.0922, Smoothness Loss = 0.0000, Contrastive Loss = 1.5764, Train Accuracy Category = 0.9263, Train Accuracy Polarity = 0.9701
# Step 300: Total Loss = 0.4235, CCE Loss Category = 0.1770, CCE Loss Polarity = 0.0883, Smoothness Loss = 0.0000, Contrastive Loss = 1.5814, Train Accuracy Category = 0.9246, Train Accuracy Polarity = 0.9713
# Step 400: Total Loss = 0.4284, CCE Loss Category = 0.1797, CCE Loss Polarity = 0.0910, Smoothness Loss = 0.0000, Contrastive Loss = 1.5773, Train Accuracy Category = 0.9250, Train Accuracy Polarity = 0.9701
# Epoch 20 Training Loss: 0.4294
# Epoch 20 Training CCE Loss Category: 0.1804
# Epoch 20 Training CCE Loss Polarity: 0.0913
# Epoch 20 Training Smoothness Loss: 0.0000
# Epoch 20 Training Contrastive Loss: 1.5767
# Epoch 20 Training Accuracy Category: 0.9248
# Epoch 20 Training Accuracy Polarity: 0.9696
# Epoch 20 Validation Loss: 0.5426
# Epoch 20 Validation CCE Loss Category: 0.2615
# Epoch 20 Validation CCE Loss Polarity: 0.1154
# Epoch 20 Validation Smoothness Loss: 0.0000
# Epoch 20 Validation Contrastive Loss: 1.6565
# Epoch 20 Validation Accuracy Category: 0.9168
# Epoch 20 Validation Accuracy Polarity: 0.9623
# Epoch 20 Duration: 61.84 seconds
#
# Total Training Time: 1114.85 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_training_history(history):
    epochs = range(1, len(history['train_loss']) + 1)

    # Collect all metrics to plot
    metrics_to_plot = [
        ('train_loss', 'Training Loss'),
        ('val_loss', 'Validation Loss'),
        ('train_cce_loss_category', 'Train CCE Loss Category'),
        ('val_cce_loss_category', 'Val CCE Loss Category'),
        ('train_cce_loss_polarity', 'Train CCE Loss Polarity'),
        ('val_cce_loss_polarity', 'Val CCE Loss Polarity'),
        ('train_smoothness_loss', 'Train Smoothness Loss'),
        ('val_smoothness_loss', 'Val Smoothness Loss'),
        ('train_contrastive_loss', 'Train Contrastive Loss'),
        ('val_contrastive_loss', 'Val Contrastive Loss'),
        ('train_accuracy_category', 'Train Accuracy Category'),
        ('val_accuracy_category', 'Val Accuracy Category'),
        ('train_accuracy_polarity', 'Train Accuracy Polarity'),
        ('val_accuracy_polarity', 'Val Accuracy Polarity'),
        ('epoch_time', 'Epoch Duration')
    ]

    # Normalize all metrics to 0-1 range for plotting
    normalized_metrics = {}
    for key, label in metrics_to_plot:
        data = history[key]
        min_val = min(data)
        max_val = max(data)
        if max_val - min_val == 0:
            # Avoid division by zero
            normalized_data = [0.0 for _ in data]
        else:
            normalized_data = [(x - min_val) / (max_val - min_val) for x in data]
        normalized_metrics[label] = normalized_data

    # Plot all metrics on the same plot
    plt.figure(figsize=(8, 4))

    for label, data in normalized_metrics.items():
        plt.plot(epochs, data, label=label)

    plt.title('Training Metrics Over Epochs (Normalized)')
    plt.xlabel('Epochs')
    plt.ylabel('Normalized Value')
    plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
    plt.tight_layout()
    plt.show()


# After training is complete
plot_training_history(history)

# Display total training time
print(f"Total Training Time: {total_training_time:.2f} seconds")
# Out:
# Total Training Time: 1114.85 seconds

# %%
# -------------------------------
# 6. Evaluation and Visualization
# -------------------------------

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Predict on the test set
all_predictions_category = []
all_predictions_polarity = []
all_labels_category = []
all_labels_polarity = []
all_resonance_scores = []

for batch_inputs, batch_labels_category, batch_labels_polarity in test_dataset:
    input_ids = batch_inputs['input_ids']
    attention_masks = batch_inputs['attention_masks']
    adjacency = batch_inputs['adjacency']

    predictions = model.predict([input_ids, attention_masks, adjacency])
    predictions_category = predictions[0]
    predictions_polarity = predictions[1]
    resonance_scores = predictions[2]
    # features = predictions[3]  # Features from the capsule network

    predicted_labels_category = np.argmax(predictions_category, axis=1)
    predicted_labels_polarity = np.argmax(predictions_polarity, axis=1)

    all_predictions_category.extend(predicted_labels_category)
    all_predictions_polarity.extend(predicted_labels_polarity)
    all_labels_category.extend(batch_labels_category.numpy())
    all_labels_polarity.extend(batch_labels_polarity.numpy())
    all_resonance_scores.extend(resonance_scores)

# Convert lists to numpy arrays
all_labels_category = np.array(all_labels_category)
all_predictions_category = np.array(all_predictions_category)
all_labels_polarity = np.array(all_labels_polarity)
all_predictions_polarity = np.array(all_predictions_polarity)

# Calculate metrics for Category
accuracy_category = accuracy_score(all_labels_category, all_predictions_category)
f1_category = f1_score(all_labels_category, all_predictions_category, average='macro')
precision_category = precision_score(all_labels_category, all_predictions_category, average='macro')
recall_category = recall_score(all_labels_category, all_predictions_category, average='macro')

print(f"Test Accuracy (Category): {accuracy_category:.4f}")
print(f"Test Macro F1 Score (Category): {f1_category:.4f}")
print(f"Test Macro Precision (Category): {precision_category:.4f}")
print(f"Test Macro Recall (Category): {recall_category:.4f}")

# Calculate metrics for Polarity
accuracy_polarity = accuracy_score(all_labels_polarity, all_predictions_polarity)
f1_polarity = f1_score(all_labels_polarity, all_predictions_polarity, average='macro')
precision_polarity = precision_score(all_labels_polarity, all_predictions_polarity, average='macro')
recall_polarity = recall_score(all_labels_polarity, all_predictions_polarity, average='macro')

print(f"Test Accuracy (Polarity): {accuracy_polarity:.4f}")
print(f"Test Macro F1 Score (Polarity): {f1_polarity:.4f}")
print(f"Test Macro Precision (Polarity): {precision_polarity:.4f}")
print(f"Test Macro Recall (Polarity): {recall_polarity:.4f}")


plt.figure(figsize=(4, 4))
# Confusion Matrix for Category
cm_category = confusion_matrix(all_labels_category, all_predictions_category)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_category, display_labels=category_encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation=90)
plt.title('Confusion Matrix - Category')
plt.show()

plt.figure(figsize=(4, 4))
# Confusion Matrix for Polarity
cm_polarity = confusion_matrix(all_labels_polarity, all_predictions_polarity)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_polarity, display_labels=polarity_encoder.classes_)
disp.plot(cmap='Greens', xticks_rotation=90)
plt.title('Confusion Matrix - Polarity')
plt.show()
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 111ms/step
# Test Accuracy (Category): 0.9168
# Test Macro F1 Score (Category): 0.9105
# Test Macro Precision (Category): 0.9173
# Test Macro Recall (Category): 0.9096
# Test Accuracy (Polarity): 0.9623
# Test Macro F1 Score (Polarity): 0.9620
# Test Macro Precision (Polarity): 0.9621
# Test Macro Recall (Polarity): 0.9619

# %%
# -------------------------------
# 6. Evaluation and Visualization
# -------------------------------

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import matplotlib
import numpy as np

# Specify the font path
font_path = r"F:\Context-Resonance Transformer\TiroBangla-Regular.ttf"

# Add the font properties
font_prop = fm.FontProperties(fname=font_path)
matplotlib.rcParams['font.family'] = font_prop.get_name()

# Function to decode tokens
def decode_tokens(input_ids, tokenizer):
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    return tokens


def visualize_resonance_and_attention(tokens, resonance_scores, self_attention_scores, cross_attention_scores,
                                      predicted_label_category, predicted_label_polarity,
                                      label_encoder_category, label_encoder_polarity, attention_mask=None):
    """
    Plots resonance scores and attention scores for each token in the sentence, excluding padding and special tokens.
    """
    # Convert tensors to numpy
    if tf.is_tensor(tokens):
        tokens = tokens.numpy()
    if tf.is_tensor(resonance_scores):
        resonance_scores = resonance_scores.numpy()
    if tf.is_tensor(self_attention_scores):
        self_attention_scores = self_attention_scores.numpy()
    if tf.is_tensor(cross_attention_scores):
        cross_attention_scores = cross_attention_scores.numpy()

    
    if attention_mask is not None:
        valid_indices = attention_mask > 0
        tokens = np.array(tokens)[valid_indices]
        resonance_scores = resonance_scores[valid_indices]
        self_attention_scores = self_attention_scores[:, :, valid_indices, :][:, :, :, valid_indices]
        cross_attention_scores = cross_attention_scores[:, :, valid_indices, :][:, :, :, valid_indices]

    # Exclude special tokens [CLS], [SEP], and [PAD] 
    special_tokens = {'[CLS]', '[SEP]', '[PAD]'}
    mask = ~np.isin(tokens, list(special_tokens))
    tokens = np.array(tokens)[mask]
    resonance_scores = resonance_scores[mask]
    self_attention_scores = self_attention_scores[:, :, mask, :][:, :, :, mask]
    cross_attention_scores = cross_attention_scores[:, :, mask, :][:, :, :, mask]

    # Plot Resonance Scores
    plt.figure(figsize=(8, 4))
    plt.bar(range(len(tokens)), resonance_scores, color='skyblue')
    plt.xticks(range(len(tokens)), tokens, rotation=90, fontproperties=font_prop)
    plt.title(f"Resonance Scores\nPredicted Category: {label_encoder_category.inverse_transform([predicted_label_category])[0]}, "
              f"Predicted Polarity: {label_encoder_polarity.inverse_transform([predicted_label_polarity])[0]}",
              fontproperties=font_prop)
    plt.xlabel("Tokens", fontproperties=font_prop)
    plt.ylabel("Resonance Score", fontproperties=font_prop)
    plt.tight_layout()
    plt.show()

    # Average attention scores over heads
    avg_self_attention = np.mean(self_attention_scores[0], axis=0) 
    avg_cross_attention = np.mean(cross_attention_scores[0], axis=0)

    # Plot Self-Attention Scores
    plt.figure(figsize=(6, 4))
    sns.heatmap(avg_self_attention, xticklabels=tokens, yticklabels=tokens, cmap='viridis')
    plt.xticks(rotation=90, fontproperties=font_prop)
    plt.yticks(rotation=0, fontproperties=font_prop)
    plt.title("Self-Attention Scores", fontproperties=font_prop)
    plt.xlabel("Key Tokens", fontproperties=font_prop)
    plt.ylabel("Query Tokens", fontproperties=font_prop)
    plt.tight_layout()
    plt.show()

    # Plot Cross-Attention Scores
    plt.figure(figsize=(6, 4))
    sns.heatmap(avg_cross_attention, xticklabels=tokens, yticklabels=tokens, cmap='plasma')
    plt.xticks(rotation=90, fontproperties=font_prop)
    plt.yticks(rotation=0, fontproperties=font_prop)
    plt.title("Cross-Attention Scores", fontproperties=font_prop)
    plt.xlabel("Key Tokens (GNN Output)", fontproperties=font_prop)
    plt.ylabel("Query Tokens (BERT Output)", fontproperties=font_prop)
    plt.tight_layout()
    plt.show()

# Visualizing Resonance Scores and Attention Maps for a Sample Sentence
def visualize_sample_resonance_and_attention(input_ids, attention_mask, adjacency, label_encoder_category, label_encoder_polarity, sample_index=0):
    """
    Visualizes resonance scores and attention maps for a single sample.
    """
    sample_input_ids = input_ids[sample_index:sample_index+1]
    sample_attention_masks = attention_mask[sample_index:sample_index+1]
    sample_adjacency = adjacency[sample_index:sample_index+1]
    sample_label_category = y_test_category[sample_index]
    sample_label_polarity = y_test_polarity[sample_index]

    # Predict sentiment and get resonance scores and attention scores
    predictions = model.predict([sample_input_ids, sample_attention_masks, sample_adjacency])
    predictions_category = predictions[0]
    predictions_polarity = predictions[1]
    resonance_scores = predictions[2]
    features = predictions[3]
    self_attention_scores = predictions[4]
    cross_attention_scores = predictions[5]

    predicted_label_category = np.argmax(predictions_category, axis=1)[0]
    predicted_label_polarity = np.argmax(predictions_polarity, axis=1)[0]

    # Decode tokens
    tokens = decode_tokens(sample_input_ids[0], tokenizer)

    # Extract and normalize resonance scores
    resonance = resonance_scores[0].squeeze()
    # Adjust the length to match the tokens
    resonance = resonance[:len(tokens)]

    # Ensure resonance is float32 to match plotting
    resonance_normalized = (resonance - np.min(resonance)) / (np.max(resonance) - np.min(resonance) + 1e-8)
    resonance_normalized = resonance_normalized.astype(np.float32)

    # Extract attention mask for the sample
    attention_mask_sample = sample_attention_masks[0]

    # Visualize resonance scores and attention maps
    visualize_resonance_and_attention(
        tokens=tokens,
        resonance_scores=resonance_normalized,
        self_attention_scores=self_attention_scores,
        cross_attention_scores=cross_attention_scores,
        predicted_label_category=predicted_label_category,
        predicted_label_polarity=predicted_label_polarity,
        label_encoder_category=label_encoder_category,
        label_encoder_polarity=label_encoder_polarity,
        attention_mask=attention_mask_sample 
    )

# %%
visualize_sample_resonance_and_attention(X_test_ids, X_test_masks, adjacency_test, category_encoder, polarity_encoder, sample_index=0)
# Out:
# 1/1 [==============================] - 0s 428ms/step
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2474 (\N{BENGALI LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2486 (\N{BENGALI LETTER SHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2509 (\N{BENGALI SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2458 (\N{BENGALI LETTER CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2495 (\N{BENGALI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2478 (\N{BENGALI LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2455 (\N{BENGALI LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2480 (\N{BENGALI LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2494 (\N{BENGALI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2503 (\N{BENGALI VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2447 (\N{BENGALI LETTER E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2463 (\N{BENGALI LETTER TTA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2498 (\N{BENGALI VOWEL SIGN UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2482 (\N{BENGALI LETTER LA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2479 (\N{BENGALI LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2476 (\N{BENGALI LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2489 (\N{BENGALI LETTER HA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2472 (\N{BENGALI LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2474 (\N{BENGALI LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2486 (\N{BENGALI LETTER SHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2509 (\N{BENGALI SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2458 (\N{BENGALI LETTER CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2495 (\N{BENGALI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2478 (\N{BENGALI LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2455 (\N{BENGALI LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2480 (\N{BENGALI LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2494 (\N{BENGALI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2503 (\N{BENGALI VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2447 (\N{BENGALI LETTER E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2463 (\N{BENGALI LETTER TTA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2498 (\N{BENGALI VOWEL SIGN UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2482 (\N{BENGALI LETTER LA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2479 (\N{BENGALI LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2476 (\N{BENGALI LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2489 (\N{BENGALI LETTER HA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# f:\Mini Conda\envs\env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2472 (\N{BENGALI LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.

# %%
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt

# Stack all features and labels from the test set
all_features = []
all_labels_category = []

for batch_inputs, batch_labels_category_batch, _ in test_dataset:
    input_ids = batch_inputs['input_ids']
    attention_masks = batch_inputs['attention_masks']
    adjacency = batch_inputs['adjacency']

    predictions = model.predict([input_ids, attention_masks, adjacency])
    features = predictions[3]  # Features from the capsule network
    all_features.append(features)

    # Collect labels
    all_labels_category.extend(batch_labels_category_batch.numpy())

# Convert lists to arrays
all_features = np.vstack(all_features)
all_labels_category = np.array(all_labels_category)

# Debugging prints
print("Shape of all_features:", all_features.shape)
print("Shape of all_labels_category:", all_labels_category.shape)
print("Number of NaN in all_features:", np.isnan(all_features).sum())
print("Number of infinite values in all_features:", np.isinf(all_features).sum())
print("Unique labels:", np.unique(all_labels_category))

# Ensure labels are integers and 1D
all_labels_category = all_labels_category.astype(int)
all_labels_category = all_labels_category.flatten()

# Apply t-SNE
tsne = TSNE(n_components=2, random_state=42)
features_2d = tsne.fit_transform(all_features)

# Check that dimensions match
print("Length of features_2d:", len(features_2d))
print("Length of all_labels_category:", len(all_labels_category))

# Plot the features
plt.figure(figsize=(8,6))
scatter = plt.scatter(features_2d[:,0], features_2d[:,1], c=all_labels_category, cmap='viridis', alpha=0.7)

# Create a legend with unique labels
handles, _ = scatter.legend_elements()
unique_labels = np.unique(all_labels_category)
plt.legend(handles, category_encoder.inverse_transform(unique_labels), title="Categories")
plt.title('t-SNE Visualization of Feature Embeddings')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()
# Out:
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# Shape of all_features: (1646, 3200)
# Shape of all_labels_category: (1646,)
# Number of NaN in all_features: 0
# Number of infinite values in all_features: 0
# Unique labels: [0 1 2 3 4]
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# Length of features_2d: 1646
# Length of all_labels_category: 1646
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
# findfont: Font family 'Noto Sans Bengali Condensed' not found.
